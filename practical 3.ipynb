# %% [markdown]
# Name: Ankita Kalyankar
# Roll no: 13225
# Class: TE (B1)

# %%
import pandas as pd

# %%
df=pd.read_csv("fake_real_job_postings_3000x25.csv")

# %%
df.head(6)
# Out:
#    job_id                    job_title  \
# 0       1            Software Engineer
# 1       2               Content Writer
# 2       3  Customer Support Specialist
# 3       4                 Data Analyst
# 4       5             Graphic Designer
# 5       6            Marketing Manager
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
# 5  We are looking for knowledge development exper...
#
#                                         requirements  \
# 0  Candidates should have dynamic team skills fas...
# 1  Candidates should have required team fast-pace...
# 2  Candidates should have preferred knowledge opp...
# 3  Candidates should have innovation team require...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   job_id                     3000 non-null   int64
#  1   job_title                  3000 non-null   object
#  2   job_description            3000 non-null   object
#  3   requirements               3000 non-null   object
#  4   benefits                   3000 non-null   object
#  5   company_name               1528 non-null   object
#  6   company_profile            3000 non-null   object
#  7   industry                   3000 non-null   object
#  8   employment_type            3000 non-null   object
#  9   location                   3000 non-null   object
#  10  salary_range               3000 non-null   object
#  11  required_experience_years  3000 non-null   int64
#  12  education_level            3000 non-null   object
# ...

# %%
df.describe()
# Out:
#             job_id  required_experience_years    has_logo  num_open_positions  \
# count  3000.000000                3000.000000  3000.00000         3000.000000
# mean   1500.500000                   5.044000     0.24600            5.564000
# std     866.169729                   3.168292     0.43075            2.890102
# min       1.000000                   0.000000     0.00000            1.000000
# 25%     750.750000                   2.000000     0.00000            3.000000
# 50%    1500.500000                   5.000000     0.00000            6.000000
# 75%    2250.250000                   8.000000     0.00000            8.000000
# max    3000.000000                  10.000000     1.00000           10.000000
#
#        telecommuting  text_length      is_fake
# count    3000.000000  3000.000000  3000.000000
# mean        0.507667    79.186667     0.490667
# std         0.500025     9.999924     0.499996
# min         0.000000    69.000000     0.000000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.columns.names
# Out:
# FrozenList([None])

# %%
df.columns.values
# Out:
# array(['job_id', 'job_title', 'job_description', 'requirements',
#        'benefits', 'company_name', 'company_profile', 'industry',
#        'employment_type', 'location', 'salary_range',
#        'required_experience_years', 'education_level', 'department',
#        'posting_date', 'application_deadline', 'contact_email',
#        'company_website', 'has_logo', 'num_open_positions',
#        'job_function', 'telecommuting', 'fraud_reason', 'text_length',
#        'is_fake'], dtype=object)

# %%
df.dtypes
# Out:
# job_id                        int64
# job_title                    object
# job_description              object
# requirements                 object
# benefits                     object
# company_name                 object
# company_profile              object
# industry                     object
# employment_type              object
# location                     object
# salary_range                 object
# required_experience_years     int64
# education_level              object
# department                   object
# posting_date                 object
# application_deadline         object
# contact_email                object
# company_website              object
# has_logo                      int64
# num_open_positions            int64
# job_function                 object
# telecommuting                 int64
# fraud_reason                 object
# text_length                   int64
# is_fake                       int64
# dtype: object

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'job_description', 'requirements', 'benefits',
#        'company_name', 'company_profile', 'industry', 'employment_type',
#        'location', 'salary_range', 'required_experience_years',
#        'education_level', 'department', 'posting_date', 'application_deadline',
#        'contact_email', 'company_website', 'has_logo', 'num_open_positions',
#        'job_function', 'telecommuting', 'fraud_reason', 'text_length',
#        'is_fake'],
#       dtype='object')

# %%
df.iloc[1500]
# Out:
# job_id                                                                    1501
# job_title                                                     Graphic Designer
# job_description              We are looking for growth responsibilities req...
# requirements                 Candidates should have opportunity innovation ...
# benefits                     We offer experience fast-paced knowledge requi...
# company_name                                                        Company_79
# company_profile              Our company knowledge skills dynamic collabora...
# industry                                                                Retail
# employment_type                                                       Contract
# location                                                                Remote
# salary_range                                                     Not Disclosed
# required_experience_years                                                   10
# ...

# %%
df.company_profile.iloc[1500]
# Out:
# 'Our company knowledge skills dynamic collaboration development experience required development opportunity collaboration strategy opportunity fast-paced support development experience dynamic skills innovation required support dynamic dynamic strategy development fast-paced required experience required growth'

# %%
df.iloc[:,5:13]
# Out:
#      company_name                                    company_profile  \
# 0     Company_543  Our company growth fast-paced responsibilities...
# 1     Company_192  Our company fast-paced opportunity innovation ...
# 2             NaN  We are global innovation growth skills knowled...
# 3      Company_95  Our company fast-paced support team strategy i...
# 4             NaN  We are global experience skills preferred fast...
# ...           ...                                                ...
# 2995  Company_159  Our company growth required innovation collabo...
# 2996          NaN  We are global experience knowledge knowledge d...
# 2997          NaN  We are global dynamic innovation strategy grow...
# 2998          NaN  We are global required growth opportunity dyna...
# 2999  Company_354  Our company responsibilities knowledge collabo...
#
#         industry employment_type         location   salary_range  \
# 0      Marketing        Contract  Toronto, Canada      $60k-$80k
# ...

# %%
df.iloc[15:30,4:10]
# Out:
#                                              benefits company_name  \
# 15  We offer required support strategy growth grow...          NaN
# 16  We offer dynamic responsibilities responsibili...          NaN
# 17  We offer skills development strategy knowledge...          NaN
# 18  We offer fast-paced fast-paced strategy prefer...          NaN
# 19  We offer strategy development support required...  Company_313
# 20  We offer dynamic growth collaboration team kno...          NaN
# 21  We offer strategy required innovation growth k...  Company_668
# 22  We offer development responsibilities support ...  Company_242
# 23  We offer team strategy preferred team collabor...  Company_704
# 24  We offer dynamic skills skills collaboration k...  Company_319
# 25  We offer responsibilities team skills fast-pac...  Company_485
# 26  We offer skills fast-paced knowledge support i...          NaN
# 27  We offer development support growth required t...  Company_512
# ...

# %%
df.num_open_positions.min()
# Out:
# 1

# %%
df.job_function.sum()
# Out:
# '...'
