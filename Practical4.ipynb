# %% [markdown]
# Name: Ankita Kalyankar Roll no: 13225 Class: TE (B1) Title: Creation of Dataset using Microsoft Excel.3. Identification and Handling of Outliers

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("MYdataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MathScore          35 non-null     float64
#  1   Reading_score      39 non-null     float64
#  2   Writing_score	     41 non-null     float64
#  3   Performance_score  41 non-null     float64
#  4   Club_joindate      37 non-null     float64
# dtypes: float64(5)
# memory usage: 1.8 KB

# %%
df=pd.read_csv("MYdataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MathScore          35 non-null     float64
#  1   Reading_score      39 non-null     float64
#  2   Writing_score	     41 non-null     float64
#  3   Performance_score  41 non-null     float64
#  4   Club_joindate      37 non-null     float64
# dtypes: float64(5)
# memory usage: 1.8 KB

# %%
df.fillna(39)
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0             39.0               89.0
# 2        39.0           70.0             48.0               19.0
# 3        39.0           83.0             78.0               75.0
# 4        60.0          113.0             85.0               39.0
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10       39.0           77.0             81.0               71.0
# 11       39.0          114.0             86.0               32.0
# 12       39.0           75.0             96.0               49.0
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0              NaN               89.0
# 2         NaN           70.0             48.0               19.0
# 3         NaN           83.0             78.0               75.0
# 4        60.0          113.0             85.0                NaN
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10        NaN           77.0             81.0               71.0
# 11        NaN          114.0             86.0               32.0
# 12        NaN           75.0             96.0               49.0
# ...

# %%
df.head(15)
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0              NaN               89.0
# 2         NaN           70.0             48.0               19.0
# 3         NaN           83.0             78.0               75.0
# 4        60.0          113.0             85.0                NaN
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10        NaN           77.0             81.0               71.0
# 11        NaN          114.0             86.0               32.0
# 12        NaN           75.0             96.0               49.0
# ...

# %%
df.describe()
# Out:
#        MathScore  Reading_score  Writing_score\t  Performance_score  \
# count  35.000000      39.000000        41.000000          41.000000
# mean   42.114286      92.871795        66.414634          48.780488
# std    12.885860      14.979248        20.549910          24.265729
# min    20.000000      70.000000        35.000000          11.000000
# 25%    29.500000      80.500000        47.000000          30.000000
# 50%    45.000000      89.000000        68.000000          48.000000
# 75%    52.500000     103.000000        85.000000          74.000000
# max    60.000000     120.000000       100.000000          90.000000
#
#        Club_joindate
# count      37.000000
# mean     2021.864865
# std         1.475017
# min      2020.000000
# 25%      2020.000000
# 50%      2022.000000
# 75%      2023.000000
# max      2024.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MathScore          35 non-null     float64
#  1   Reading_score      39 non-null     float64
#  2   Writing_score	     41 non-null     float64
#  3   Performance_score  41 non-null     float64
#  4   Club_joindate      37 non-null     float64
# dtypes: float64(5)
# memory usage: 1.8 KB

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0              NaN               89.0
# 2         NaN           70.0             48.0               19.0
# 3         NaN           83.0             78.0               75.0
# 4        60.0          113.0             85.0                NaN
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10        NaN           77.0             81.0               71.0
# 11        NaN          114.0             86.0               32.0
# 12        NaN           75.0             96.0               49.0
# ...

# %%
df.MathScore.fillna(89)
# Out:
# 0     47.0
# 1     59.0
# 2     89.0
# 3     89.0
# 4     60.0
# 5     20.0
# 6     44.0
# 7     44.0
# 8     47.0
# 9     24.0
# 10    89.0
# 11    89.0
# 12    89.0
# 13    89.0
# 14    89.0
# 15    60.0
# 16    49.0
# 17    56.0
# 18    36.0
# 19    53.0
# 20    55.0
# 21    21.0
# 22    56.0
# 23    37.0
# 24    45.0
# 25    22.0
# 26    51.0
# 27    48.0
# 28    30.0
# 29    50.0
# 30    27.0
# 31    30.0
# 32    54.0
# 33    55.0
# 34    23.0
# 35    52.0
# 36    26.0
# 37    29.0
# 38    43.0
# 39    43.0
# 40    51.0
# 41    27.0
# Name: MathScore, dtype: float64

# %%
df.columns.values
# Out:
# array(['MathScore', 'Reading_score', 'Writing_score\t',
#        'Performance_score', 'Club_joindate'], dtype=object)

# %%
df.iloc[20]
# Out:
# MathScore              55.0
# Reading_score          80.0
# Writing_score\t        70.0
# Performance_score      48.0
# Club_joindate        2023.0
# Name: 20, dtype: float64

# %%
df.iloc[:,2:4]
# Out:
#     Writing_score\t  Performance_score
# 0              36.0               23.0
# 1               NaN               89.0
# 2              48.0               19.0
# 3              78.0               75.0
# 4              85.0                NaN
# 5              64.0               62.0
# 6              35.0               17.0
# 7              90.0               50.0
# 8              88.0               69.0
# 9              88.0               48.0
# 10             81.0               71.0
# 11             86.0               32.0
# 12             96.0               49.0
# 13             65.0               19.0
# 14             58.0               30.0
# 15             41.0               87.0
# 16             36.0               49.0
# 17             45.0               37.0
# 18             64.0               76.0
# 19             43.0               32.0
# 20             70.0               48.0
# 21             35.0               14.0
# 22             57.0               11.0
# ...

# %%
df.math_score.fillna(20, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26744\238073082.py in ?()
# ----> 1 df.math_score.fillna(20, inplace=True)
#
# ~\anaconda5\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'math_score'

# %%
df['MathScore']=df['MathScore'].fillna(89)

# %%
df.MathScore.isna().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0              NaN               89.0
# 2        89.0           70.0             48.0               19.0
# 3        89.0           83.0             78.0               75.0
# 4        60.0          113.0             85.0                NaN
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10       89.0           77.0             81.0               71.0
# 11       89.0          114.0             86.0               32.0
# 12       89.0           75.0             96.0               49.0
# ...
