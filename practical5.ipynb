# %% [markdown]
# Name: Ankita Kalyankar
# Class: TE (B1)
# Roll no: 13225
# Title: 1. Creation of Dataset using Microsoft Excel.
# 2. Identification and Handling of Outliers
# 3. Data Transformation for the purpose of : a. To change the scale for better understanding b. To decrease the skewness and convert distribution into normal distribution.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("MYdataset.csv")

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0        47.0           84.0             36.0               23.0
# 1        59.0           71.0              NaN               89.0
# 2         NaN           70.0             48.0               19.0
# 3         NaN           83.0             78.0               75.0
# 4        60.0          113.0             85.0                NaN
# 5        20.0          100.0             64.0               62.0
# 6        44.0          117.0             35.0               17.0
# 7        44.0           87.0             90.0               50.0
# 8        47.0           84.0             88.0               69.0
# 9        24.0           89.0             88.0               48.0
# 10        NaN           77.0             81.0               71.0
# 11        NaN          114.0             86.0               32.0
# 12        NaN           75.0             96.0               49.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MathScore          35 non-null     float64
#  1   Reading_score      39 non-null     float64
#  2   Writing_score	     41 non-null     float64
#  3   Performance_score  41 non-null     float64
#  4   Club_joindate      37 non-null     float64
#  5   Placement_offer    42 non-null     int64
# dtypes: float64(5), int64(1)
# memory usage: 2.1 KB

# %%
df.describe()
# Out:
#        MathScore  Reading_score  Writing_score\t  Performance_score  \
# count  35.000000      39.000000        41.000000          41.000000
# mean   42.114286      92.871795        66.414634          48.780488
# std    12.885860      14.979248        20.549910          24.265729
# min    20.000000      70.000000        35.000000          11.000000
# 25%    29.500000      80.500000        47.000000          30.000000
# 50%    45.000000      89.000000        68.000000          48.000000
# 75%    52.500000     103.000000        85.000000          74.000000
# max    60.000000     120.000000       100.000000          90.000000
#
#        Club_joindate  Placement_offer
# count      37.000000        42.000000
# mean     2021.864865         2.000000
# std         1.475017         0.826394
# min      2020.000000         1.000000
# 25%      2020.000000         1.000000
# 50%      2022.000000         2.000000
# 75%      2023.000000         3.000000
# max      2024.000000         3.000000

# %%
df.isnull().sum()
# Out:
# MathScore            7
# Reading_score        3
# Writing_score\t      1
# Performance_score    1
# Club_joindate        5
# Placement_offer      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(17)

# %%
df.MathScore.max()
# Out:
# 60.0

# %%
df.MathScore.min()
# Out:
# 20.0

# %%
df.MathScore.mean()
# Out:
# np.float64(42.114285714285714)

# %%
x=df.MathScore.mean()

# %%
df.MathScore.fillna(x, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22000\2689485329.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.MathScore.fillna(x, inplace=True)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0   47.000000           84.0             36.0               23.0
# 1   59.000000           71.0              NaN               89.0
# 2   42.114286           70.0             48.0               19.0
# 3   42.114286           83.0             78.0               75.0
# 4   60.000000          113.0             85.0                NaN
# 5   20.000000          100.0             64.0               62.0
# 6   44.000000          117.0             35.0               17.0
# 7   44.000000           87.0             90.0               50.0
# 8   47.000000           84.0             88.0               69.0
# 9   24.000000           89.0             88.0               48.0
# 10  42.114286           77.0             81.0               71.0
# 11  42.114286          114.0             86.0               32.0
# 12  42.114286           75.0             96.0               49.0
# ...

# %%
df.Reading_score.mean()
# Out:
# np.float64(92.87179487179488)

# %%
y=df.Reading_score.mean()

# %%
y = df['Reading_score'].mean()
df.loc[:, 'Reading_score'] = df['Reading_score'].fillna(y)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score\t  Performance_score  \
# 0   47.000000      84.000000             36.0               23.0
# 1   59.000000      71.000000              NaN               89.0
# 2   42.114286      70.000000             48.0               19.0
# 3   42.114286      83.000000             78.0               75.0
# 4   60.000000     113.000000             85.0                NaN
# 5   20.000000     100.000000             64.0               62.0
# 6   44.000000     117.000000             35.0               17.0
# 7   44.000000      87.000000             90.0               50.0
# 8   47.000000      84.000000             88.0               69.0
# 9   24.000000      89.000000             88.0               48.0
# 10  42.114286      77.000000             81.0               71.0
# 11  42.114286     114.000000             86.0               32.0
# 12  42.114286      75.000000             96.0               49.0
# ...

# %%
df.columns
# Out:
# Index(['MathScore', 'Reading_score', 'Writing_score\t', 'Performance_score',
#        'Club_joindate', 'Placement_offer'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['MathScore', 'Reading_score', 'Writing_score', 'Performance_score',
#        'Club_joindate', 'Placement_offer'],
#       dtype='object')

# %%
df.Writing_score.mean()
# Out:
# np.float64(66.41463414634147)

# %%
z=df.Writing_score.mean()

# %%
z = df['Writing_score'].mean()
df.loc[:, 'Writing_score'] = df['Writing_score'].fillna(z)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score  Performance_score  Club_joindate  \
# 0   47.000000      84.000000      36.000000               23.0         2024.0
# 1   59.000000      71.000000      66.414634               89.0         2024.0
# 2   42.114286      70.000000      48.000000               19.0            NaN
# 3   42.114286      83.000000      78.000000               75.0         2020.0
# 4   60.000000     113.000000      85.000000                NaN         2024.0
# 5   20.000000     100.000000      64.000000               62.0         2022.0
# 6   44.000000     117.000000      35.000000               17.0         2022.0
# 7   44.000000      87.000000      90.000000               50.0         2023.0
# 8   47.000000      84.000000      88.000000               69.0         2020.0
# 9   24.000000      89.000000      88.000000               48.0         2023.0
# 10  42.114286      77.000000      81.000000               71.0         2020.0
# ...

# %%
df.iloc[4:5, 2:3] = df.iloc[4:5, 3:4].fillna(35)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score  Performance_score  Club_joindate  \
# 0   47.000000      84.000000      36.000000               23.0         2024.0
# 1   59.000000      71.000000      66.414634               89.0         2024.0
# 2   42.114286      70.000000      48.000000               19.0            NaN
# 3   42.114286      83.000000      78.000000               75.0         2020.0
# 4   60.000000     113.000000      35.000000                NaN         2024.0
# 5   20.000000     100.000000      64.000000               62.0         2022.0
# 6   44.000000     117.000000      35.000000               17.0         2022.0
# 7   44.000000      87.000000      90.000000               50.0         2023.0
# 8   47.000000      84.000000      88.000000               69.0         2020.0
# 9   24.000000      89.000000      88.000000               48.0         2023.0
# 10  42.114286      77.000000      81.000000               71.0         2020.0
# ...

# %%
df['Club_joindate'] = df['Club_joindate'].fillna(2019)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score  Performance_score  Club_joindate  \
# 0   47.000000      84.000000      36.000000               23.0         2024.0
# 1   59.000000      71.000000      66.414634               89.0         2024.0
# 2   42.114286      70.000000      48.000000               19.0         2019.0
# 3   42.114286      83.000000      78.000000               75.0         2020.0
# 4   60.000000     113.000000      35.000000                NaN         2024.0
# 5   20.000000     100.000000      64.000000               62.0         2022.0
# 6   44.000000     117.000000      35.000000               17.0         2022.0
# 7   44.000000      87.000000      90.000000               50.0         2023.0
# 8   47.000000      84.000000      88.000000               69.0         2020.0
# 9   24.000000      89.000000      88.000000               48.0         2023.0
# 10  42.114286      77.000000      81.000000               71.0         2020.0
# ...

# %%
df.Performance_score.mean()
# Out:
# np.float64(48.78048780487805)

# %%
p=df.Performance_score.mean()

# %%
df.Performance_score.fillna(p,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22000\3765353809.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Performance_score.fillna(p,inplace=True)

# %%
df
# Out:
#     MathScore  Reading_score  Writing_score  Performance_score  Club_joindate  \
# 0   47.000000      84.000000      36.000000          23.000000         2024.0
# 1   59.000000      71.000000      66.414634          89.000000         2024.0
# 2   42.114286      70.000000      48.000000          19.000000         2019.0
# 3   42.114286      83.000000      78.000000          75.000000         2020.0
# 4   60.000000     113.000000      35.000000          48.780488         2024.0
# 5   20.000000     100.000000      64.000000          62.000000         2022.0
# 6   44.000000     117.000000      35.000000          17.000000         2022.0
# 7   44.000000      87.000000      90.000000          50.000000         2023.0
# 8   47.000000      84.000000      88.000000          69.000000         2020.0
# 9   24.000000      89.000000      88.000000          48.000000         2023.0
# 10  42.114286      77.000000      81.000000          71.000000         2020.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# MathScore            0
# Reading_score        0
# Writing_score        0
# Performance_score    0
# Club_joindate        0
# Placement_offer      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['MathScore', 'Reading_score', 'Writing_score', 'Performance_score',
#        'Club_joindate', 'Placement_offer'],
#       dtype='object')

# %%
cols=['MathScore', 'Reading_score', 'Writing_score', 'Performance_score',
       'Club_joindate','Placement_offer']

# %%
df.boxplot(cols)
# Out:
# <Axes: >

# %%
plt.show()

# %%
cols1=['MathScore', 'Reading_score', 'Writing_score', 'Performance_score']

# %%
df.boxplot(cols1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.scatterplot(Performance_score,Placement_offer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 plt.scatterplot(Performance_score,Placement_offer)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig,ax=plt.subplots(figsize=(12,10))

# %%
ax.scatter(df['Performance_score'],df['Placement_offer'])

# %%
plt.show()

# %%
df.describe()
# Out:
#        MathScore  Reading_score  Writing_score  Performance_score  \
# count  42.000000      42.000000      42.000000          42.000000
# mean   42.114286      92.871795      65.224158          48.780488
# std    11.734401      14.420817      20.644429          23.967979
# min    20.000000      70.000000      35.000000          11.000000
# 25%    31.500000      81.500000      45.500000          30.500000
# 50%    43.000000      91.935897      66.707317          48.000000
# 75%    51.000000     103.000000      84.500000          73.250000
# max    60.000000     120.000000     100.000000          90.000000
#
#        Club_joindate  Placement_offer
# count      42.000000        42.000000
# mean     2021.523810         2.000000
# std         1.670958         0.826394
# min      2019.000000         1.000000
# 25%      2020.000000         1.000000
# 50%      2021.500000         2.000000
# 75%      2023.000000         3.000000
# max      2024.000000         3.000000

# %%
q1=np.percentile(df.MathScore,25)

# %%
q2=np.percentile(df.MathScore,50)

# %%
q3=np.percentile(df.MathScore,75)

# %%
IQR=q3-q1

# %%
float(IQR)
# Out:
# 19.5

# %%
upper_bod=q3+1.5*IQR

# %%
float(upper_bod)
# Out:
# 80.25

# %%
lower_bod=q1-1.5*IQR

# %%
float(lower_bod)
# Out:
# 2.25
