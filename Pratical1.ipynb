# %%
print("Hello This is First Practical")
# Out:
# Hello This is First Practical

# %%
x=[10,20,30,40]

# %%
x.insert(2,25)

# %%
print(x)
# Out:
# [10, 20, 25, 30, 40]

# %%
p={}

# %%
print("Type of the given var:",type(p))
# Out:
# Type of the given var: <class 'dict'>

# %%
print("For display of empty set")
# Out:
# For display of empty set

# %%
p=set()

# %%
print("Empty set=",p)
# Out:
# Empty set= set()

# %%
print("Adding value in dict")
# Out:
# Adding value in dict

# %%
product={"pid":1}

# %%
product={"pid":1,"pname":"book"}

# %%
product["price"]=200

# %%
print("Final Dict:",product)
# Out:
# Final Dict: {'pid': 1, 'pname': 'book', 'price': 200}

# %%
print("question 5 is: a=(4,5,7,20) and tuple cannot be edited")
# Out:
# question 5 is: a=(4,5,7,20) and tuple cannot be edited

# %%
print("Printing only students in dict")
# Out:
# Printing only students in dict

# %%
student={'Rollno':101,'Name':'Ankita'}

# %%
print("Displaying student Names:",student['Name'])
# Out:
# Displaying student Names: Ankita
